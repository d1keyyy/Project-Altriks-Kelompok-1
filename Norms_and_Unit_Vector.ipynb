# %% [markdown]
# <a href="https://colab.research.google.com/github/d1keyyy/Project-Altriks-Kelompok-1/blob/main/Norms_and_Unit_Vector.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ### SOAL NOMOR 1

# %%
import numpy as np

# %%
# buat vector x dengan ukuran 3x1
X = np.array([[1],
             [2],
             [3]])
X
# Out:
# array([[1],
#        [2],
#        [3]])

# %%
# hitung nilai L2 norm dari vector x
(1**2 + 2**2 + 3**2)**(1/2)
np.linalg.norm(X)
# Out:
# np.float64(3.7416573867739413)

# %% [markdown]
# ### SOAL NOMOR 2

# %%
# buat vector v dengan elemen (3,4)
V = np.array ([3, 4])
V
# Out:
# array([3, 4])

# %%
# hitung nilai L2 norm dari vector v
(3**2 + 4**2)**(1/2)
V_norm = np.linalg.norm(V)
V_norm
# Out:
# np.float64(5.0)

# %%
# tampilkan unit vector dari vector v
unit_V = V / V_norm
unit_V
# Out:
# array([0.6, 0.8])

# %%
# hitung panjang unit vector dari vector v
np.linalg.norm(unit_V)
# Out:
# np.float64(1.0)
