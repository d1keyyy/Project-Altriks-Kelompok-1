# %% [markdown]
# <a href="https://colab.research.google.com/github/d1keyyy/Project-Altriks-Kelompok-1/blob/main/Exercises_on_Algebra_Data_Structures.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np

# %%
# selesaikan soal berikut
X = np.array([[25],
              [2],
              [-3],
              [-23]])
X
# Out:
# array([[ 25],
#        [  2],
#        [ -3],
#        [-23]])

# %%
X_t = X.T
X_t
# Out:
# array([[ 25,   2,  -3, -23]])
