# %% [markdown]
# <a href="https://colab.research.google.com/github/d1keyyy/Project-Altriks-Kelompok-1/blob/main/Matrix_Tensor.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ### SOAL NOMOR 1

# %%
import numpy as np

# %%
# buat matrix X berukuran 2x3 menggunakan numpy
X = np.array ([[19,21], [67,69], [420,41]])
X
# Out:
# array([[ 19,  21],
#        [ 67,  69],
#        [420,  41]])

# %%
# tampilkan ukuran dari matrix X
X.size
# Out:
# 6

# %%
# tampilkan seluruh elemen dari kolom pertama dari matrix X
X[0,:]
# Out:
# array([19, 21])

# %%
# tampilkan seluruh elemen dari baris kedua dari matrix X
X[:,1]
# Out:
# array([21, 69, 41])

# %% [markdown]
# ### SOAL NOMOR 2

# %%
import torch
import tensorflow as tf

# %%
# ulangi soal nomor 1 menggunakan pytorch
X_torch = torch.tensor([[19,21], [67,69], [420,41]])
X_torch
# Out:
# tensor([[ 19,  21],
#         [ 67,  69],
#         [420,  41]])

# %%
X_torch.size()
# Out:
# torch.Size([3, 2])

# %%
X_torch[0,:]
# Out:
# tensor([19, 21])

# %%
X_torch[:,1]
# Out:
# tensor([21, 69, 41])

# %%
# ulangi soal nomor 1 menggunakan tensorflow
X_tf = tf.constant([[19,21], [67,69], [420,41]])
X_tf
# Out:
# <tf.Tensor: shape=(3, 2), dtype=int32, numpy=
# array([[ 19,  21],
#        [ 67,  69],
#        [420,  41]], dtype=int32)>

# %%
X_tf.shape
# Out:
# TensorShape([3, 2])

# %%
X_tf[0,:]
# Out:
# <tf.Tensor: shape=(2,), dtype=int32, numpy=array([19, 21], dtype=int32)>

# %%
X_tf[:,1]
# Out:
# <tf.Tensor: shape=(3,), dtype=int32, numpy=array([21, 69, 41], dtype=int32)>
