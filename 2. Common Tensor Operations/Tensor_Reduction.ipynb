# %% [markdown]
# <a href="https://colab.research.google.com/github/d1keyyy/Project-Altriks-Kelompok-1/blob/main/Tensor_Reduction.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import tensorflow as tf
import torch

# %% [markdown]
# ### SOAL NOMOR 1

# %%
# buat matrix X dengan ukuran 2x3 menggunakan numpy
X = np.array([[12, 24], [78, 33], [22, 90]])
X
# Out:
# array([[12, 24],
#        [78, 33],
#        [22, 90]])

# %%
# buat matrix X_pt dengan ukuran 2x3 menggunakan pytorch
X_pt = torch.tensor ([[12, 24], [78, 33], [22, 90]])
X_pt
# Out:
# tensor([[12, 24],
#         [78, 33],
#         [22, 90]])

# %%
# buat matrix X_tf dengan ukuran 2x3 menggunakan tensorflow
X_tf = tf.constant([[12, 24,], [78, 33], [22, 90]])
X_tf
# Out:
# <tf.Tensor: shape=(3, 2), dtype=int32, numpy=
# array([[12, 24],
#        [78, 33],
#        [22, 90]], dtype=int32)>

# %% [markdown]
# ### SOAL NOMOR 2

# %%
# hitung hasil penjumlahan seluruh elemen matrix X
X.sum()
# Out:
# np.int64(259)

# %%
# hitung hasil penjumlahan seluruh elemen matrix X_pt
X_pt.sum()
# Out:
# tensor(259)

# %%
# hitung hasil penjumlahan seluruh elemen matrix X_tf
tf.reduce_sum(X_tf)
# Out:
# <tf.Tensor: shape=(), dtype=int32, numpy=259>

# %% [markdown]
# ### SOAL NOMOR 3

# %%
# hitung hasil penjumlahan matrix X berdasarkan row nya
X.sum(axis=1)
# Out:
# array([ 36, 111, 112])

# %%
# hitung hasil penjumlahan matrix X_pt berdasarkan row nya
X_pt.sum(axis=1)
# Out:
# tensor([ 36, 111, 112])

# %%
# hitung hasil penjumlahan matrix X_tf berdasarkan row nya
tf.reduce_sum(X_tf, axis=1)
# Out:
# <tf.Tensor: shape=(3,), dtype=int32, numpy=array([ 36, 111, 112], dtype=int32)>

# %% [markdown]
# ### SOAL NOMOR 4

# %%
# hitung hasil penjumlahan matrix X berdasarkan kolom nya
X.sum(axis=0)
# Out:
# array([112, 147])

# %%
# hitung hasil penjumlahan matrix X_pt berdasarkan kolom nya
X_pt.sum(axis=0)
# Out:
# tensor([112, 147])

# %%
# hitung hasil penjumlahan matrix X_tf berdasarkan kolom nya
tf.reduce_sum(X_tf, axis=0)
# Out:
# <tf.Tensor: shape=(2,), dtype=int32, numpy=array([112, 147], dtype=int32)>

# %% [markdown]
# ### SOAL NOMOR 5

# %%
# hitung nilai minimal dari matrix X, X_pt dan X_tf
X.min()
# Out:
# np.int64(12)

# %%
# hitung nilai maksimal dari matrix X, X_pt dan X_tf
X.max()
# Out:
# np.int64(90)

# %%
# hitung nilai rata-rata dari matrix X, X_pt dan X_tf
X.mean()
# Out:
# np.float64(43.166666666666664)

# %% [markdown]
# ### SOAL NOMOR 6

# %%
# hitung hasil perkalian seluruh elemen matrix X
X.prod()
# Out:
# np.int64(1467797760)

# %%
# hitung hasil perkalian seluruh elemen matrix X_pt
X_pt.prod()
# Out:
# tensor(1467797760)

# %%
# hitung hasil perkalian seluruh elemen matrix X_tf
tf.reduce_prod(X_tf)
# Out:
# <tf.Tensor: shape=(), dtype=int32, numpy=1467797760>
