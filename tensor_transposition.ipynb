# %% [markdown]
# <a href="https://colab.research.google.com/github/d1keyyy/Project-Altriks-Kelompok-1/blob/main/tensor_transposition.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# tensor transposition

# %% [markdown]
# No.1

# %%
# buat matrix X dengan ukuran 2x3 menggunakan numpy
import numpy as np
X = np.array([[25, 2, 7], [5, 26, 3]])
X
# Out:
# array([[25,  2,  7],
#        [ 5, 26,  3]])

# %%
# buat matrix X_pt dengan ukuran 2x3 menggunakan pytorch
import torch
X_pt = torch.tensor([[25, 2, 3], [5, 26, 7]])
X_pt
# Out:
# tensor([[25,  2,  3],
#         [ 5, 26,  7]])

# %%
# buat matrix X_tf dengan ukuran 2x3 menggunakan tensorflow
import tensorflow as tf
X_tf = tf.Variable([[25, 2, 3], [5, 26, 7]])
X_tf
# Out:
# <tf.Variable 'Variable:0' shape=(2, 3) dtype=int32, numpy=
# array([[25,  2,  3],
#        [ 5, 26,  7]], dtype=int32)>

# %% [markdown]
# No.2

# %%
# lakukan transpose pada matrix X
X.T
# Out:
# array([[25,  5],
#        [ 2, 26],
#        [ 7,  3]])

# %%
# lakukan transpose pada matrix X_pt
X_pt.T
# Out:
# tensor([[25,  5],
#         [ 2, 26],
#         [ 3,  7]])

# %%
# lakukan transpose pada matrix X_tf
tf.transpose(X_tf)
# Out:
# <tf.Tensor: shape=(3, 2), dtype=int32, numpy=
# array([[25,  5],
#        [ 2, 26],
#        [ 3,  7]], dtype=int32)>
