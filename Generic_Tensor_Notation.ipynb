# %% [markdown]
# <a href="https://colab.research.google.com/github/d1keyyy/Project-Altriks-Kelompok-1/blob/main/Generic_Tensor_Notation.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import torch
import tensorflow as tf

# %%
# jelaskan tentang perintah ini
images_pt = torch.zeros([32, 28, 28, 3])

# %% [markdown]
# # **PENJELASAN**
#
# 1. Apa itu torch.zeros ?
# torch.zeros adalah sebuah fungsi dalam library PyTorch yang digunakan untuk membuat tensor (matriks/wadah data) yang seluruh elemen atau isinya adalah angka nol
#
# 2. Maksud dari [32, 28, 28, 3]
# Batch Size	32	Menunjukkan ada 32 buah gambar dalam satu grup (batch) ini.
# Height	28	Tinggi setiap gambar adalah 28 piksel.
# Width	28	Lebar setiap gambar adalah 28 piksel.
# Channels	3	Jumlah saluran warna. Angka 3 biasanya merujuk pada format RGB (Red, Green, Blue).
