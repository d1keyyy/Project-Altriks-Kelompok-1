# %% [markdown]
# <a href="https://colab.research.google.com/github/d1keyyy/Project-Altriks-Kelompok-1/blob/main/The_Dot_Product.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import tensorflow as tf
import torch

# %% [markdown]
# ### SOAL NOMOR 1

# %%
# buat vector x dan y dengan ukuran 1x3 menggunakan numpy
X = np.array([1, 2, 3])
Y = np.array([4, 5, 6])

# %%
# buat vector x_pt dan y_pt dengan ukuran 1x3 menggunakan pytorch
X_pt = torch.tensor([1, 2, 3], dtype=torch.float32)
Y_pt = torch.tensor([4, 5, 6], dtype=torch.float32)

# %%
# buat vector x_tf dan y_tf dengan ukuran 1x3 menggunakan tensorflow
X_tf = tf.constant([1, 2, 3], dtype=tf.float32)
Y_tf = tf.constant([4, 5, 6], dtype=tf.float32)

# %% [markdown]
# ### SOAL NOMOR 2

# %%
# hitung perkalian dot product antara vector x dan vector y
np.dot(X, Y)
# Out:
# np.int64(32)

# %%
torch.dot(X_pt, Y_pt)
# Out:
# tensor(32.)

# %%
# hitung perkalian dot product antara vector x_tf dan vector y_tf
tf.tensordot(X_tf, Y_tf, axes=1)
# Out:
# <tf.Tensor: shape=(), dtype=float32, numpy=32.0>

# %% [markdown]
# ### SOAL NOMOR 3 ![image.png](data:image/png;base64,...)

# %%
# Exercise 1
y = np.array([
    [42, 4, 7, 99],
    [-99, -3, 17, 22]
])

y_transpose = y.T

print(y_transpose)
# Out:
# [[ 42 -99]
#  [  4  -3]
#  [  7  17]
#  [ 99  22]]

# %%
# Exercise 2
A = np.array([
    [25, 10],
    [-2, 1]
])

B = np.array([
    [-1, 7],
    [10, 8]
])

hadamard_product = np.multiply(A, B)

print(hadamard_product)
# Out:
# [[-25  70]
#  [-20   8]]

# %%
# Exercise 3
w = np.array([-1, 2, -2])
x = np.array([5, 10, 0])

dot_product = np.dot(w, x)

print(dot_product)
# Out:
# 15
